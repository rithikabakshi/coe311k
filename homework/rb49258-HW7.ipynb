# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x, y):
    return -2 * y * np.cos(x)
    
def euler(step):
    # Define parameters
    h = step  # step size
    x_start, x_end = 0, 10*np.pi
    num_steps = int((x_end - x_start) / h)

    x_values = np.linspace(x_start, x_end, num_steps + 1)
    y_values = np.zeros(num_steps + 1)


    # Initial condition
    y_values[0] = 1  # y(0) = 1

    # Implement Euler's method

    for i in range(num_steps):

        y_values[i + 1] = y_values[i] + h * f(x_values[i], y_values[i])
        
    return x_values, y_values

# %%
stepsize = np.arange(0,1,0.05)
stepsize[0] = 0.01

plt.figure(figsize=(12, 8))
xref, yref = euler(0.01)
for i in stepsize:
    x_values, y_values = euler(i)
    
    y_ref_on_cur_grid = np.interp(x_values, xref, yref)
    pointwise_error = y_values - y_ref_on_cur_grid
    total_error = np.sum(np.abs(pointwise_error))

    print(f"\nStep size h = ",i)
    print(f"Total accumulated error: {total_error:.8f}")

    # Plot the results

    plt.plot(x_values, y_values, label=f"Step size = {i:.2f}")

plt.xlabel('x')

plt.ylabel('y')

plt.title("Approximation of dy/dx = -2ycos(x) using Euler's Method")

plt.legend()

plt.show()
# Out:
# Step size h =  0.01
# Total accumulated error: 0.00000000
#
# Step size h =  0.05
# Total accumulated error: 560.44779705
#
# Step size h =  0.1
# Total accumulated error: 431.38122487
#
# Step size h =  0.15000000000000002
# Total accumulated error: 333.01123976
#
# Step size h =  0.2
# Total accumulated error: 268.51517455
#
# Step size h =  0.25
# Total accumulated error: 222.57784428
#
# Step size h =  0.30000000000000004
# Total accumulated error: 189.98836498
#
# Step size h =  0.35000000000000003
# Total accumulated error: 165.43867890
#
# Step size h =  0.4
# Total accumulated error: 146.78151277
#
# Step size h =  0.45
# Total accumulated error: 130.95865508
#
# Step size h =  0.5
# Total accumulated error: 118.33858897
#
# Step size h =  0.55
# Total accumulated error: 109.09580550
#
# Step size h =  0.6000000000000001
# Total accumulated error: 99.52090955
#
# Step size h =  0.65
# Total accumulated error: 91.57046911
#
# Step size h =  0.7000000000000001
# ...

# %%
# average the y values of for each run of h
