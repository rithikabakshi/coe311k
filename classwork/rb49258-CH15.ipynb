# %%
import numpy as np
import matplotlib.pyplot as plt

# Function representing dy/dx = -2y
def f(x, y):
    return -2 * y
    
def euler(step):
    # Define parameters
    h = step  # step size
    x_start, x_end = 0, 2
    num_steps = int((x_end - x_start) / h)

    x_values = np.linspace(x_start, x_end, num_steps + 1)
    y_values = np.zeros(num_steps + 1)


    # Initial condition
    y_values[0] = 1  # y(0) = 1

    # Implement Euler's method

    for i in range(num_steps):

        y_values[i + 1] = y_values[i] + h * f(x_values[i], y_values[i])
        
    return x_values, y_values

# %%
plt.figure(figsize=(12, 8))
xref, yref = euler(0.01)
for i in np.arange(0.01, 1, 0.05):
    x_values, y_values = euler(i)
    
    y_ref_on_cur_grid = np.interp(x_values, xref, yref)
    pointwise_error = y_values - y_ref_on_cur_grid
    total_error = np.sum(np.abs(pointwise_error))

    print(f"\nStep size h = ",i)
    for x, err in zip(x_values, pointwise_error):
        print(f"{x:.4f}\t{err:.8f}")
    print(f"Total accumulated error: {total_error:.8f}")

    # Plot the results

    plt.plot(x_values, y_values, label=f"Step size = {i:.2f}")

plt.xlabel('x')

plt.ylabel('y')

plt.title("Approximation of dy/dx = -2y using Euler's Method")

plt.legend()

plt.show()
# Out:
# Step size h =  0.01
# 0.0000	0.00000000
# 0.0100	0.00000000
# 0.0200	0.00000000
# 0.0300	0.00000000
# 0.0400	0.00000000
# 0.0500	0.00000000
# 0.0600	0.00000000
# 0.0700	0.00000000
# 0.0800	0.00000000
# 0.0900	0.00000000
# 0.1000	0.00000000
# 0.1100	0.00000000
# 0.1200	0.00000000
# 0.1300	0.00000000
# 0.1400	0.00000000
# 0.1500	0.00000000
# 0.1600	0.00000000
# 0.1700	0.00000000
# 0.1800	0.00000000
# 0.1900	0.00000000
# 0.2000	0.00000000
# 0.2100	0.00000000
# 0.2200	0.00000000
# 0.2300	0.00000000
# 0.2400	0.00000000
# 0.2500	0.00000000
# 0.2600	0.00000000
# 0.2700	0.00000000
# 0.2800	0.00000000
# 0.2900	0.00000000
# 0.3000	0.00000000
# 0.3100	0.00000000
# 0.3200	0.00000000
# 0.3300	0.00000000
# 0.3400	0.00000000
# 0.3500	0.00000000
# 0.3600	0.00000000
# 0.3700	0.00000000
# 0.3800	0.00000000
# 0.3900	0.00000000
# 0.4000	0.00000000
# 0.4100	0.00000000
# 0.4200	0.00000000
# 0.4300	0.00000000
# 0.4400	0.00000000
# 0.4500	0.00000000
# 0.4600	0.00000000
# 0.4700	0.00000000
# 0.4800	0.00000000
# 0.4900	0.00000000
# 0.5000	0.00000000
# 0.5100	0.00000000
# 0.5200	0.00000000
# 0.5300	0.00000000
# 0.5400	0.00000000
# 0.5500	0.00000000
# 0.5600	0.00000000
# 0.5700	0.00000000
# 0.5800	0.00000000
# 0.5900	0.00000000
# 0.6000	0.00000000
# 0.6100	0.00000000
# 0.6200	0.00000000
# 0.6300	0.00000000
# 0.6400	0.00000000
# 0.6500	0.00000000
# 0.6600	0.00000000
# 0.6700	0.00000000
# 0.6800	0.00000000
# 1.8500	0.00000000
# 1.8600	0.00000000
# 1.8700	0.00000000
# 1.8800	0.00000000
# 1.8900	0.00000000
# 1.9000	0.00000000
# 1.9100	0.00000000
# 1.9200	0.00000000
# 1.9300	0.00000000
# 1.9400	0.00000000
# 1.9500	0.00000000
# 1.9600	0.00000000
# 1.9700	0.00000000
# 1.9800	0.00000000
# 1.9900	0.00000000
# 2.0000	0.00000000
# Total accumulated error: 0.00000000
#
# Step size h =  0.060000000000000005
# 0.0000	0.00000000
# 0.0600	-0.00584238
# 0.1200	-0.01031672
# 0.1800	-0.01366333
# 0.2400	-0.01608498
# 0.3000	-0.01775240
# 0.3600	-0.01880904
# 0.4200	-0.01937507
# 0.4800	-0.01955090
# 0.5400	-0.01942014
# 0.6000	-0.01905217
# 0.6600	-0.01850433
# 0.7200	-0.01782377
# 0.7800	-0.01704909
# 0.8400	-0.01621163
# 0.9000	-0.01533672
# 0.9600	-0.01444459
# 1.0200	-0.01355127
# 1.0800	-0.01266925
# 1.1400	-0.01180812
# 1.2000	-0.01097508
# 1.2600	-0.01017534
# 1.3200	-0.00941252
# 1.3800	-0.00868893
# 1.4400	-0.00800583
# 1.5000	-0.00736366
# 1.5600	-0.00676218
# 1.6200	-0.00620067
# 1.6800	-0.00567801
# 1.7400	-0.00519279
# 1.8000	-0.00474341
# 1.8600	-0.00432812
# 1.9200	-0.00394509
# 1.9800	-0.00359246
# 2.0000	-0.00345608
# Total accumulated error: 0.39578608
#
# Step size h =  0.11
# 0.0000	0.00000000
# 0.1100	-0.02073135
# 0.2200	-0.03277070
# 0.3300	-0.03885348
# 0.4400	-0.04094930
# 0.5500	-0.04046311
# 0.6600	-0.03838558
# 0.7700	-0.03540523
# 0.8800	-0.03199166
# 0.9900	-0.02845716
# 1.1000	-0.02500207
# 1.2100	-0.02174806
# 1.3200	-0.01876229
# 1.4300	-0.01607494
# 1.5400	-0.01369179
# 1.6500	-0.01160311
# 1.7600	-0.00978991
# 1.8700	-0.00822826
# 1.9800	-0.00689218
# 2.0000	-0.00662382
# Total accumulated error: 0.44642401
#
# Step size h =  0.16000000000000003
# 0.0000	0.00000000
# 0.1600	-0.04379772
# 0.3200	-0.06148314
# 0.4800	-0.06475342
# 0.6400	-0.06063978
# 0.8000	-0.05325549
# 0.9600	-0.04491410
# 1.1200	-0.03683890
# 1.2800	-0.02960842
# 1.4400	-0.02343278
# 1.6000	-0.01832214
# 1.7600	-0.01418737
# 1.9200	-0.01089837
# 2.0000	-0.00937713
# Total accumulated error: 0.47150877
#
# Step size h =  0.21000000000000002
# 0.0000	0.00000000
# 0.2100	-0.07425581
# 0.4200	-0.09165067
# 0.6300	-0.08494264
# 0.8400	-0.07006241
# 1.0500	-0.05424190
# 1.2600	-0.04036191
# 1.4700	-0.02923383
# 1.6800	-0.02076596
# 1.8900	-0.01453719
# 2.0000	-0.01179437
# Total accumulated error: 0.49184670
#
# Step size h =  0.26
# 0.0000	0.00000000
# 0.2600	-0.11139544
# 0.5200	-0.11934856
# 0.7800	-0.09624770
# 1.0400	-0.06923990
# 1.3000	-0.04686149
# 1.5600	-0.03055207
# 1.8200	-0.01943079
# 2.0000	-0.01383071
# Total accumulated error: 0.50690665
#
# Step size h =  0.31000000000000005
# 0.0000	0.00000000
# 0.3100	-0.15457463
# 0.6200	-0.14137004
# 0.9300	-0.09789341
# 1.2400	-0.06081315
# 1.5500	-0.03573226
# 1.8600	-0.02032634
# 2.0000	-0.01542007
# Total accumulated error: 0.52612991
#
# Step size h =  0.36000000000000004
# 0.0000	0.00000000
# 0.3600	-0.20321313
# 0.7200	-0.15509493
# 1.0800	-0.09087581
# 1.4400	-0.04837332
# 1.8000	-0.02462369
# 2.0000	-0.01655532
# Total accumulated error: 0.53873620
#
# Step size h =  0.41000000000000003
# 0.0000	0.00000000
# 0.4100	-0.25678640
# 0.8200	-0.15838236
# 1.2300	-0.07749914
# 1.6400	-0.03534815
# 2.0000	-0.01729401
# Total accumulated error: 0.54531005
#
# Step size h =  0.46
# 0.0000	0.00000000
# 0.4600	-0.31482031
# 0.9200	-0.14948307
# 1.3800	-0.06103380
# 1.8400	-0.02425857
# 2.0000	-0.01756009
# Total accumulated error: 0.56715585
#
# Step size h =  0.51
# 0.0000	0.00000000
# 0.5100	-0.37688629
# 1.0200	-0.12696782
# 1.5300	-0.04546383
# 2.0000	-0.01758843
# Total accumulated error: 0.56690636
#
# Step size h =  0.56
# 0.0000	0.00000000
# 0.5600	-0.44259694
# 1.1200	-0.08966878
# 1.6800	-0.03530027
# 2.0000	-0.01821003
# Total accumulated error: 0.58577602
#
# Step size h =  0.6100000000000001
# 0.0000	0.00000000
# 0.6100	-0.51160208
# 1.2200	-0.03663177
# 1.8300	-0.03544344
# 2.0000	-0.02461563
# Total accumulated error: 0.60829292
#
# Step size h =  0.66
# 0.0000	0.00000000
# 0.6600	-0.58358518
# 1.3200	0.03292285
# 1.9800	-0.05108115
# 2.0000	-0.04904523
# Total accumulated error: 0.71663441
#
# Step size h =  0.7100000000000001
# 0.0000	0.00000000
# 0.7100	-0.65826013
# 1.4200	0.11963211
# 2.0000	-0.04581195
# Total accumulated error: 0.82370419
#
# Step size h =  0.76
# 0.0000	0.00000000
# 0.7600	-0.73536829
# 1.5200	0.22401650
# 2.0000	-0.00677195
# Total accumulated error: 0.96615673
#
# Step size h =  0.81
# 0.0000	0.00000000
# 0.8100	-0.81467587
# 1.6200	0.34650130
# 2.0000	0.07466805
# Total accumulated error: 1.23584523
#
# Step size h =  0.8600000000000001
# 0.0000	0.00000000
# 0.8600	-0.89597157
# 1.7200	0.48743401
# 2.0000	0.21050805
# Total accumulated error: 1.59391363
#
# Step size h =  0.91
# 0.0000	0.00000000
# 0.9100	-0.97906436
# 1.8200	0.64709853
# 2.0000	0.41274805
# Total accumulated error: 2.03891094
#
# Step size h =  0.9600000000000001
# 0.0000	0.00000000
# 0.9600	-1.06378158
# 1.9200	0.82572686
# 2.0000	0.69338805
# Total accumulated error: 2.58289649
