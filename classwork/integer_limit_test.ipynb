# %%
i = 1
i = i+1
print(i)

i = 2147483647
i = i+1
print(i)
# Out:
# 2
# 2147483648

# %%
i = 1
i+2**-53 # machine epsilon value for a 53 bit mantissa number minimum value for number to add one for error
# Out:
# 1.0

# %% [markdown]
# ##### numerical stability - understanding what machine epsilon is helps to make numerically stable algorithms and control rounding errors
