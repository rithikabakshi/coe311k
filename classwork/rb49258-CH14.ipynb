# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function and the domain
f = lambda x: np.sin(x)
a, b = 0, 2 * np.pi  # Interval
N = 10  # Number of sample points

# Create a uniform grid
x = np.linspace(a, b, N)
y = f(x)

# Plot the sampled points
plt.plot(x, y, 'o-', label='Sampled Points')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Uniform Sampling of f(x) = sin(x)')
plt.legend()
plt.show()

# %%
# Step size
h = (b - a) / (N - 1)
print(h)
print(x)
# Out:
# 0.6981317007977318
# [0.         0.6981317  1.3962634  2.0943951  2.7925268  3.4906585
#  4.1887902  4.88692191 5.58505361 6.28318531]

# %%
# Central Difference Approximation for the derivative
cent_df_dx = (f(x + h) - f(x - h)) / (2 * h)

# Plot the approximation and the true derivative
plt.plot(x, np.cos(x), label='Exact Derivative')
plt.plot(x, cent_df_dx, 'o--', label='Central Difference Approximation')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("Approximating Derivative of f(x) = sin(x) using Central Difference")
plt.legend()
plt.show()

# %%
# Forward Difference Approximation for the derivative
for_df_dx = (f(x + h) - f(x)) / (h)

# Plot the approximation and the true derivative
plt.plot(x, np.cos(x), label='Exact Derivative')
plt.plot(x, for_df_dx, 'o--', label='Forward Difference Approximation')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("Approximating Derivative of f(x) = sin(x) using Forward Difference")
plt.legend()
plt.show()

# %%
# Backward Difference Approximation for the derivative
back_df_dx = (f(x) - f(x - h)) / (h)

# Plot the approximation and the true derivative
plt.plot(x, np.cos(x), label='Exact Derivative')
plt.plot(x, back_df_dx, 'o--', label='Backward Difference Approximation')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("Approximating Derivative of f(x) = sin(x) using Backward Difference")
plt.legend()
plt.show()

# %%
plt.subplot(2, 2, 1) # (row, column, active area)
plt.plot(x, y, 'o-', label='Sampled Points')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Uniform Sampling')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x), label='Exact Derivative')
plt.plot(x, cent_df_dx, 'o--', label='Central Difference Approximation')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("Central Difference")
plt.legend()

plt.subplot(2, 2, 3) # (row, column, active area)
plt.plot(x, np.cos(x), label='Exact Derivative')
plt.plot(x, for_df_dx, 'o--', label='Forward Difference Approximation')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("Forward Difference")
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(x, np.cos(x), label='Exact Derivative')
plt.plot(x, back_df_dx, 'o--', label='Backward Difference Approximation')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("Backward Difference")
plt.legend()
plt.show()

# %% [markdown]
# 4 Subplots for n = 10, approximation starts to be inaccurate based on the type of difference being used.

# %%
# Define the function and the domain
f = lambda x: np.sin(x)
a, b = 0, 2 * np.pi  # Interval
N = 50  # Number of sample points

# Create a uniform grid
x = np.linspace(a, b, N)
y = f(x)

# Plot the sampled points
plt.plot(x, y, 'o-', label='Sampled Points')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Uniform Sampling of f(x) = sin(x)')
plt.legend()
plt.show()

# Step size
h = (b - a) / (N - 1)

# %%
# Central Difference Approximation for the derivative
cent_df_dx = (f(x + h) - f(x - h)) / (2 * h)

# Plot the approximation and the true derivative
plt.plot(x, np.cos(x), label='Exact Derivative')
plt.plot(x, cent_df_dx, 'o--', label='Central Difference Approximation')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("Approximating Derivative of f(x) = sin(x) using Central Difference")
plt.legend()
plt.show()

# %%
# Forward Difference Approximation for the derivative
for_df_dx = (f(x + h) - f(x)) / (h)

# Plot the approximation and the true derivative
plt.plot(x, np.cos(x), label='Exact Derivative')
plt.plot(x, for_df_dx, 'o--', label='Forward Difference Approximation')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("Approximating Derivative of f(x) = sin(x) using Forward Difference")
plt.legend()
plt.show()

# %%
# Backward Difference Approximation for the derivative
back_df_dx = (f(x) - f(x - h)) / (h)

# Plot the approximation and the true derivative
plt.plot(x, np.cos(x), label='Exact Derivative')
plt.plot(x, back_df_dx, 'o--', label='Backward Difference Approximation')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("Approximating Derivative of f(x) = sin(x) using Backward Difference")
plt.legend()
plt.show()

# %%
plt.subplot(2, 2, 1) # (row, column, active area)
plt.plot(x, y, 'o-', label='Sampled Points')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Uniform Sampling')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x), label='Exact Derivative')
plt.plot(x, cent_df_dx, 'o--', label='Central Difference Approximation')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("Central Difference")
plt.legend()

plt.subplot(2, 2, 3) # (row, column, active area)
plt.plot(x, np.cos(x), label='Exact Derivative')
plt.plot(x, for_df_dx, 'o--', label='Forward Difference Approximation')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("Forward Difference")
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(x, np.cos(x), label='Exact Derivative')
plt.plot(x, back_df_dx, 'o--', label='Backward Difference Approximation')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("Backward Difference")
plt.legend()
plt.show()

# %% [markdown]
# When the number of sample points increases to 50, it also decreases the step size. This means that the n=50 plots are more accurate when using Euler's method.
