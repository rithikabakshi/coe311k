# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def leibniz(terms):
    sum = 0
    for n in range(0,terms):
        sum+=((-1)**n)/(2*n+1)
        if(n%100==0):
            print("rel err: ",(abs(np.pi-sum*4)/np.pi))
    return sum
# Out:
#   File "<ipython-input-2-b11298ebb77c>", line 7
#     return sum
#     ^
# SyntaxError: invalid syntax

# %%
test = leibniz(5000)
print(test*4)
relErr = np.pi-test*4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f4da872fd1fb> in <module>
# ----> 1 test = leibniz(5000)
#       2 print(test*4)
#       3 relErr = np.pi-test*4
#
# NameError: name 'leibniz' is not defined
