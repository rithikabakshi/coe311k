# %% [markdown]
# I'm about to write my first Jupyter notebook in Python

# %% [markdown]
# # hello

# %% [markdown]
# ##subheading!

# %% [markdown]
# #heading

# %% [markdown]
# # heading

# %% [markdown]
# #heading again

# %% [markdown]
# # why isnt it working

# %% [markdown]
# ## never mind

# %%
print("hello world")
# Out:
# hello world
