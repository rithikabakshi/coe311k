# %%
import numpy as np

# %%
# jacobian
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %%
A = np.array([[10,-1,2,0,0],[-1,11,-1,3,0],[2,-1,10,-1,0],[0,3,-1,8,-2],[0,0,0,-2,9]])
b = np.array([14,30,26,25,37])
A = A.astype(float)
b = b.astype(float)
x0 = np.zeros_like(b)
tol = 1*(10**-6)
max_iterations = 100

# %%
# %%time
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
# Out:
# Solution: [0.99999995 2.00000025 2.99999986 4.00000008 4.99999983]
# Iterations: 18
# CPU times: user 3.86 ms, sys: 0 ns, total: 3.86 ms
# Wall time: 3.51 ms

# %% [markdown]
# Jacobi method --> problem A
# - took 18 iterations to converge to a solution
# - time to run: 2.98 ms

# %%
# gauss-seidel
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
            # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %%
A = np.array([[10,-1,2,0,0],[-1,11,-1,3,0],[2,-1,10,-1,0],[0,3,-1,8,-2],[0,0,0,-2,9]])
b = np.array([14,30,26,25,37])
A = A.astype(float)
b = b.astype(float)
x0 = np.zeros_like(b)
tol = 1*(10**-6)
max_iterations = 100

# %%
# %%time
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
# Out:
# Solution: [1.00000003 2.00000002 2.99999999 3.99999998 5.        ]
# Iterations: 10
# CPU times: user 858 µs, sys: 334 µs, total: 1.19 ms
# Wall time: 1.18 ms

# %% [markdown]
# Gauss-Seidel method --> problem A
# - took 10 iterations to converge to a solution
# - time to run: 2.68 ms

# %%
A = np.array([[1,2,3,0,0],[2,1,2,3,0],[3,2,1,2,3],[0,3,2,1,2],[0,0,3,2,1]])
b = np.array([14,22,33,26,22])
A = A.astype(float)
b = b.astype(float)
x0 = np.zeros_like(b)
tol = 1*(10**-6)
max_iterations = 100

# %%
# %%time
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
# Out:
# Solution: [-3.43010894e+85 -4.24934579e+85 -5.28966155e+85 -4.24934579e+85
#  -3.43010894e+85]
# Iterations: 100
# CPU times: user 8.99 ms, sys: 4.42 ms, total: 13.4 ms
# Wall time: 11.9 ms

# %% [markdown]
# Jacobi Method --> problem B
# - took until max_iterations, meaning it did not converge to a solution within 100 iterations
# - time to run: 11.2 ms

# %%
A = np.array([[1,2,3,0,0],[2,1,2,3,0],[3,2,1,2,3],[0,3,2,1,2],[0,0,3,2,1]])
b = np.array([14,22,33,26,22])
A = A.astype(float)
b = b.astype(float)
x0 = np.zeros_like(b)
tol = 1*(10**-6)
max_iterations = 100

# %%
# %%time
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
# Out:
# Solution: [-8.70303388e+112  3.37515847e+113 -5.07312279e+113 -1.50300774e+113
#   1.82253839e+114]
# Iterations: 100
# CPU times: user 10.9 ms, sys: 969 µs, total: 11.9 ms
# Wall time: 11 ms

# %% [markdown]
# Gauss-Seidel Method --> problem B
# - took until max_iterations, meaning it did not converge to a solution within 100 iterations
# - time to run: 8.94 ms
