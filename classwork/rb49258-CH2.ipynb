# %%
import numpy as np
def binary(x):
    arr = np.array([])
    converted = 0
    while(x!=0):
        arr = np.append(arr,x%2)
        x//=2
    for i in arr:
        a = arr[-1]
        converted =10*converted+a
        # print(converted)
        arr = arr[:-1]
        # print(arr)
    
    return int(converted)

# %%
z = binary(2025)
print(z)
# Out:
# 11111101001
